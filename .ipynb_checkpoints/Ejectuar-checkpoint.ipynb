# %%
from simular.mundial import (
    simulate_world_cup
)

from simular.stats_tracker import (
    StatsTracker
)

# %%
SIMULATIONS = 10

# %%
stats = StatsTracker()

for sim in range(SIMULATIONS):

    result = simulate_world_cup()

    stats.update(result)

    if sim % 100 == 0:

        print(
            f'Simulation {sim}'
        )

print('\n')
print('WORLD CUP 2026 PROBABILITIES')
print('\n')

champion_probs = []

for team, wins in (
    stats.champions.items()
):

    probability = (
        wins / SIMULATIONS
    )

    champion_probs.append(
        (team, probability)
    )

champion_probs = sorted(

    champion_probs,

    key=lambda x: x[1],

    reverse=True
)

for team, prob in champion_probs:

    print(
        f'{team}: {prob:.2%}'
    )
# Out:
# WARNING: Czech Republic not found
# WARNING: South Korea not found
# Czechia 0-0 Korea Republic
# xG: 1.40 - 1.20
# Probabilities: [0.3758228  0.27098513 0.35319203]
# Czechia 4-1 Mexico
# xG: 1.00 - 1.00
# Probabilities: [0.46252012 0.16866386 0.368816  ]
# Czechia 1-0 South Africa
# xG: 1.00 - 1.00
# Probabilities: [0.48466897 0.2516776  0.2636534 ]
# Korea Republic 1-0 Mexico
# xG: 1.00 - 1.00
# Probabilities: [0.53405535 0.14789774 0.31804687]
# Korea Republic 3-0 South Africa
# xG: 1.00 - 1.00
# Probabilities: [0.53139615 0.2616985  0.20690534]
# Mexico 1-0 South Africa
# xG: 1.00 - 1.00
# Probabilities: [0.639492   0.08809154 0.2724165 ]
# WARNING: Bosnia-Herzegovina not found
# Bosnia and Herzegovina 0-0 Canada
# xG: 1.00 - 1.00
# Probabilities: [0.53463465 0.14875224 0.3166131 ]
# Bosnia and Herzegovina 1-0 Qatar
# xG: 1.00 - 1.00
# Probabilities: [0.49439263 0.30292955 0.20267777]
# Bosnia and Herzegovina 0-1 Switzerland
# xG: 1.00 - 1.00
# Probabilities: [0.4346757  0.17578673 0.38953763]
# Canada 0-1 Qatar
# xG: 1.00 - 1.00
# Probabilities: [0.62297326 0.09078213 0.2862446 ]
# Canada 1-1 Switzerland
# xG: 1.00 - 1.00
# Probabilities: [0.6184099  0.08597919 0.29561093]
# Qatar 0-3 Switzerland
# xG: 1.00 - 1.00
# Probabilities: [0.36531138 0.12330075 0.5113879 ]
# Brazil 0-1 Haiti
# xG: 1.00 - 1.00
# Probabilities: [0.71722156 0.06758144 0.215197  ]
# Brazil 0-0 Morocco
# xG: 1.00 - 1.00
# Probabilities: [0.6558508  0.08363926 0.2605099 ]
# Brazil 1-0 Scotland
# xG: 1.00 - 1.00
# Probabilities: [0.67040694 0.0957129  0.23388015]
# Haiti 0-0 Morocco
# xG: 1.00 - 1.00
# Probabilities: [0.4491392  0.10242613 0.44843462]
# Haiti 2-1 Scotland
# xG: 1.00 - 1.00
# Probabilities: [0.5082727  0.11667167 0.37505558]
# Morocco 1-0 Scotland
# xG: 1.00 - 1.00
# Probabilities: [0.69326675 0.09134497 0.21538831]
# Australia 0-0 Paraguay
# xG: 1.00 - 1.00
# Probabilities: [0.6960399  0.07690457 0.22705553]
# WARNING: Turkey not found
# Australia 1-0 Türkiye
# xG: 1.00 - 1.00
# Probabilities: [0.74285656 0.03992758 0.21721584]
# WARNING: United States not found
# Australia 1-1 USA
# xG: 1.00 - 1.00
# Probabilities: [0.8249019  0.03569693 0.13940117]
# Paraguay 1-1 Türkiye
# xG: 1.00 - 1.00
# Probabilities: [0.6916273  0.05134404 0.2570286 ]
# Paraguay 3-2 USA
# xG: 1.00 - 1.00
# Probabilities: [0.7263417  0.04012679 0.23353148]
# Türkiye 0-2 USA
# xG: 1.33 - 1.31
# Probabilities: [0.42608175 0.27530414 0.29861408]
# WARNING: Ivory Coast not found
# Curaçao 1-2 Côte d'Ivoire
# xG: 1.00 - 1.00
# Probabilities: [0.38053674 0.04467351 0.57478976]
# Curaçao 3-1 Ecuador
# xG: 1.00 - 1.00
# Probabilities: [0.48349297 0.08538488 0.43112215]
# Curaçao 1-1 Germany
# xG: 1.00 - 1.00
# Probabilities: [0.4571272  0.08888371 0.4539891 ]
# Côte d'Ivoire 3-0 Ecuador
# xG: 1.00 - 1.00
# Probabilities: [0.586892  0.0987314 0.3143766]
# Côte d'Ivoire 1-2 Germany
# xG: 1.00 - 1.00
# Probabilities: [0.5760166  0.1211459  0.30283743]
# Ecuador 1-2 Germany
# xG: 1.00 - 1.00
# Probabilities: [0.5166551 0.1267952 0.3565497]
# Japan 0-1 Netherlands
# xG: 1.00 - 1.00
# Probabilities: [0.6451649  0.08868352 0.26615164]
# Japan 2-0 Sweden
# xG: 1.00 - 1.00
# Probabilities: [0.67158157 0.06121325 0.26720518]
# Japan 1-1 Tunisia
# xG: 1.00 - 1.00
# Probabilities: [0.70400476 0.07700107 0.21899414]
# Netherlands 1-0 Sweden
# xG: 1.00 - 1.00
# Probabilities: [0.7336441  0.07911498 0.18724087]
# Netherlands 0-1 Tunisia
# xG: 1.00 - 1.00
# Probabilities: [0.6895364  0.09922198 0.21124165]
# Sweden 3-0 Tunisia
# xG: 1.00 - 1.00
# Probabilities: [0.66041523 0.08516727 0.25441754]
# Belgium 2-0 Egypt
# xG: 1.00 - 1.00
# Probabilities: [0.6619792  0.05641483 0.28160596]
# WARNING: Iran not found
# Belgium 0-1 IR Iran
# xG: 1.00 - 1.00
# Probabilities: [0.83883566 0.03590883 0.12525551]
# Belgium 2-0 New Zealand
# xG: 1.00 - 1.00
# Probabilities: [0.68807495 0.09728423 0.2146408 ]
# Egypt 3-1 IR Iran
# xG: 1.00 - 1.00
# Probabilities: [0.7241476  0.05320998 0.22264236]
# Egypt 1-2 New Zealand
# xG: 1.00 - 1.00
# Probabilities: [0.63018507 0.06853793 0.30127698]
# IR Iran 1-2 New Zealand
# xG: 1.00 - 1.00
# Probabilities: [0.43339893 0.39127165 0.17532945]
# WARNING: Cape Verde not found
# Cabo Verde 2-0 Saudi Arabia
# xG: 1.00 - 1.00
# Probabilities: [0.4879404  0.21474148 0.29731813]
# Cabo Verde 1-3 Spain
# xG: 1.00 - 1.00
# Probabilities: [0.27261266 0.09859286 0.6287945 ]
# Cabo Verde 1-2 Uruguay
# xG: 1.00 - 1.00
# Probabilities: [0.5446046  0.15967971 0.29571572]
# Saudi Arabia 1-3 Spain
# xG: 1.00 - 1.00
# Probabilities: [0.46989775 0.09245785 0.43764436]
# Saudi Arabia 1-0 Uruguay
# xG: 1.00 - 1.00
# Probabilities: [0.35664082 0.11948604 0.52387315]
# Spain 0-1 Uruguay
# xG: 1.00 - 1.00
# Probabilities: [0.7172238  0.08451147 0.19826476]
# France 2-1 Iraq
# xG: 1.00 - 1.00
# Probabilities: [0.6550097  0.11596262 0.22902769]
# France 1-1 Norway
# xG: 1.00 - 1.00
# Probabilities: [0.6322208  0.10767225 0.26010692]
# France 1-0 Senegal
# xG: 1.00 - 1.00
# Probabilities: [0.66036695 0.08007044 0.2595626 ]
# Iraq 3-0 Norway
# xG: 1.00 - 1.00
# Probabilities: [0.49649233 0.12343158 0.38007605]
# Iraq 0-1 Senegal
# xG: 1.00 - 1.00
# Probabilities: [0.43530786 0.10840204 0.45629016]
# Norway 2-2 Senegal
# xG: 1.00 - 1.00
# Probabilities: [0.624895   0.09458254 0.2805225 ]
# Algeria 1-1 Argentina
# xG: 1.00 - 1.00
# Probabilities: [0.35815093 0.1103552  0.53149384]
# Algeria 1-1 Austria
# xG: 1.00 - 1.00
# Probabilities: [0.66222763 0.07264104 0.26513132]
# Algeria 0-1 Jordan
# xG: 1.00 - 1.00
# Probabilities: [0.6321447  0.07278091 0.29507437]
# Argentina 1-1 Austria
# xG: 1.00 - 1.00
# Probabilities: [0.66581744 0.10985671 0.22432584]
# Argentina 2-1 Jordan
# xG: 1.00 - 1.00
# Probabilities: [0.69299096 0.09455344 0.21245559]
# Austria 1-2 Jordan
# xG: 1.00 - 1.00
# Probabilities: [0.6695494  0.05976823 0.27068233]
# WARNING: DR Congo not found
# Colombia 1-0 Congo DR
# xG: 1.00 - 1.00
# Probabilities: [0.8455941  0.04124079 0.11316516]
# Colombia 3-0 Portugal
# xG: 1.00 - 1.00
# Probabilities: [0.632758   0.08612037 0.2811216 ]
# Colombia 2-1 Uzbekistan
# xG: 1.00 - 1.00
# Probabilities: [0.6885295  0.08068478 0.23078571]
# Congo DR 3-1 Portugal
# xG: 1.00 - 1.00
# Probabilities: [0.4375198  0.22076401 0.3417162 ]
# Congo DR 0-2 Uzbekistan
# xG: 1.00 - 1.00
# Probabilities: [0.42102396 0.1923296  0.38664642]
# Portugal 0-1 Uzbekistan
# xG: 1.00 - 1.00
# Probabilities: [0.6608673  0.06080936 0.27832332]
# Croatia 3-3 England
# xG: 1.00 - 1.00
# Probabilities: [0.6478914  0.08933899 0.2627696 ]
# Croatia 2-0 Ghana
# xG: 1.00 - 1.00
# Probabilities: [0.5954021  0.13856435 0.26603353]
# Croatia 2-1 Panama
# xG: 1.00 - 1.00
# Probabilities: [0.67745525 0.07610078 0.24644396]
# England 0-0 Ghana
# xG: 1.00 - 1.00
# Probabilities: [0.70446664 0.06574334 0.22978997]
# England 0-2 Panama
# xG: 1.00 - 1.00
# Probabilities: [0.6623477  0.10237098 0.23528138]
# Ghana 0-2 Panama
# xG: 1.00 - 1.00
# Probabilities: [0.37353575 0.14801973 0.47844452]
# WARNING: South Korea not found
# WARNING: Bosnia-Herzegovina not found
# WARNING: United States not found
# WARNING: Ivory Coast not found
# WARNING: Czech Republic not found
# Simulation 0
#
#
# WORLD CUP 2026 PROBABILITIES
#
#
# Belgium: 100.00%
